# %% [markdown]
# # Portfolio 3 - Clustering Visualisation

# %% [markdown]
# K-means clustering is one of the simplest and popular unsupervised learning algorithms. Typically, unsupervised algorithms make inferences from datasets using only input vectors without referring to known, or labelled, outcomes. This notebook illustrates the process of K-means clustering by generating some random clusters of data and then showing the iterations of the algorithm as random cluster means are updated.

# %% [markdown]
# We first generate random data around 4 centers.

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import math
# %matplotlib inline

# %%
center_1 = np.array([1,2])
center_2 = np.array([6,6])
center_3 = np.array([9,1])
center_4 = np.array([-5,-1])

# Generate random data and center it to the four centers each with a different variance
np.random.seed(5)
data_1 = np.random.randn(200,2) * 1.5 + center_1
data_2 = np.random.randn(200,2) * 1 + center_2
data_3 = np.random.randn(200,2) * 0.5 + center_3
data_4 = np.random.randn(200,2) * 0.8 + center_4

data = np.concatenate((data_1, data_2, data_3, data_4), axis = 0)

plt.scatter(data[:,0], data[:,1], s=7, c='k')
plt.show()

# %% [markdown]
# ## 1. Generate random cluster centres
#
# You need to generate four random centres.
#
# This part of portfolio should contain at least:
# - The number of clusters `k` is set to 4;
# - Generate random centres via `centres = np.random.randn(k,c)*std + mean` where `std` and `mean` are the standard deviation and mean of the data. `c` represents the number of features in the data. Set the random seed to 6.
# - Color the generated centers with `green`, `blue`, `yellow`, and `cyan`. Set the edgecolors to `red`.

# %%
k = 4
mean = data.mean()
std = data.std()
colors = ['green','blue','yellow','cyan']
np.random.seed(6)

# %%
data.shape
# Out:
# (800, 2)

# %%
centres = np.random.randn(4,2)*std + mean
centres
# Out:
# array([[ 1.0430169 ,  5.53863665],
#        [ 3.33061168, -1.4938254 ],
#        [-8.35175241,  6.33448312],
#        [ 7.25803215, -4.15028729]])

# %%
plt.scatter(data[:,0], data[:,1], s=7, c='k')
plt.scatter(centres[:,0], centres[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %% [markdown]
# ### 2. Visualise the clustering results in each iteration

# %% [markdown]
# You need to implement the process of k-means clustering.  Implement each iteration as a seperate cell, assigning each data point to the closest centre, then updating the cluster centres based on the data, then plot the new clusters.
#
# Replace this text with your explaination of the algorithm.  The resulting notebook should provide a good explanation and demonstration of the K-means algorithm.

# %%
def find_center(datapoint, center):
    distance = []
    for c in center:
        dist = math.sqrt((datapoint[0] - c[0])**2 + (datapoint[1] - c[1])**2)
        distance.append(dist)
    return distance.index(min(distance))

# %% [markdown]
# ### Iteration 1

# %%
cluster = []
for datapoint in data:
    cluster.append(find_center(datapoint,centres))

mycolors = []
for c in cluster:
    mycolors.append(colors[c])

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres[:,0], centres[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres
# Out:
# array([[ 1.0430169 ,  5.53863665],
#        [ 3.33061168, -1.4938254 ],
#        [-8.35175241,  6.33448312],
#        [ 7.25803215, -4.15028729]])

# %%
newcenter = np.array([])
for c in range(len(centres)):
    mypointsx = np.array([])
    mypointsy = np.array([])
    for i in range(len(data)):
        if cluster[i] == c:
            mypointsx = np.append(mypointsx, data[i,0])
            mypointsy = np.append(mypointsy, data[i,1])
    newcenter = np.append(newcenter, [mypointsx.mean(),mypointsy.mean()])
newcenter = newcenter.reshape(4,2)
centres1 = newcenter

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres1[:,0], centres[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres
# Out:
# array([[ 1.0430169 ,  5.53863665],
#        [ 3.33061168, -1.4938254 ],
#        [-8.35175241,  6.33448312],
#        [ 7.25803215, -4.15028729]])

# %% [markdown]
# ### Iteration 2

# %%
cluster = []
for datapoint in data:
    cluster.append(find_center(datapoint,centres))

mycolors = []
for c in cluster:
    mycolors.append(colors[c])

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres[:,0], centres[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
newcenter = np.array([])
for c in range(len(centres)):
    mypointsx = np.array([])
    mypointsy = np.array([])
    for i in range(len(data)):
        if cluster[i] == c:
            mypointsx = np.append(mypointsx, data[i,0])
            mypointsy = np.append(mypointsy, data[i,1])
    newcenter = np.append(newcenter, [mypointsx.mean(),mypointsy.mean()])
newcenter = newcenter.reshape(4,2)
centres1 = newcenter

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres1[:,0], centres1[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres - centres1
# Out:
# array([[-2.95319085,  0.71850663],
#        [ 4.41170594, -1.34666949],
#        [-2.81151209,  7.02408701],
#        [-1.8361948 , -5.17225924]])

# %% [markdown]
# ### Iteration 3

# %%
cluster = []
for datapoint in data:
    cluster.append(find_center(datapoint,centres1))

mycolors = []
for c in cluster:
    mycolors.append(colors[c])

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres1[:,0], centres1[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
newcenter = np.array([])
for c in range(len(centres1)):
    mypointsx = np.array([])
    mypointsy = np.array([])
    for i in range(len(data)):
        if cluster[i] == c:
            mypointsx = np.append(mypointsx, data[i,0])
            mypointsy = np.append(mypointsy, data[i,1])
    newcenter = np.append(newcenter, [mypointsx.mean(),mypointsy.mean()])
newcenter = newcenter.reshape(4,2)
centres2 = newcenter

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres2[:,0], centres2[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres1 - centres2
# Out:
# array([[-0.90511596, -0.33017356],
#        [-1.32742461, -1.69052561],
#        [-0.46056642,  0.26793501],
#        [ 0.04186636, -0.05749055]])

# %% [markdown]
# ### Iteration 4

# %%
cluster = []
for datapoint in data:
    cluster.append(find_center(datapoint,centres2))

mycolors = []
for c in cluster:
    mycolors.append(colors[c])

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres2[:,0], centres2[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
newcenter = np.array([])
for c in range(len(centres2)):
    mypointsx = np.array([])
    mypointsy = np.array([])
    for i in range(len(data)):
        if cluster[i] == c:
            mypointsx = np.append(mypointsx, data[i,0])
            mypointsy = np.append(mypointsy, data[i,1])
    newcenter = np.append(newcenter, [mypointsx.mean(),mypointsy.mean()])
newcenter = newcenter.reshape(4,2)
centres3 = newcenter

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres3[:,0], centres3[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres2 - centres3
# Out:
# array([[-0.86306417, -0.56726935],
#        [-0.52504461, -0.48863652],
#        [-0.02250376, -0.00786858],
#        [-0.01127842,  0.03312343]])

# %% [markdown]
# ### Iteration 5

# %%
cluster = []
for datapoint in data:
    cluster.append(find_center(datapoint,centres3))

mycolors = []
for c in cluster:
    mycolors.append(colors[c])

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres3[:,0], centres3[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
newcenter = np.array([])
for c in range(len(centres3)):
    mypointsx = np.array([])
    mypointsy = np.array([])
    for i in range(len(data)):
        if cluster[i] == c:
            mypointsx = np.append(mypointsx, data[i,0])
            mypointsy = np.append(mypointsy, data[i,1])
    newcenter = np.append(newcenter, [mypointsx.mean(),mypointsy.mean()])
newcenter = newcenter.reshape(4,2)
centres4 = newcenter

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres4[:,0], centres4[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres3 - centres4
# Out:
# array([[-0.2080497 , -0.17027546],
#        [-0.16835621, -0.10679166],
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.        ]])

# %% [markdown]
# ### Iteration 6

# %%
cluster = []
for datapoint in data:
    cluster.append(find_center(datapoint,centres4))

mycolors = []
for c in cluster:
    mycolors.append(colors[c])

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres4[:,0], centres4[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
newcenter = np.array([])
for c in range(len(centres4)):
    mypointsx = np.array([])
    mypointsy = np.array([])
    for i in range(len(data)):
        if cluster[i] == c:
            mypointsx = np.append(mypointsx, data[i,0])
            mypointsy = np.append(mypointsy, data[i,1])
    newcenter = np.append(newcenter, [mypointsx.mean(),mypointsy.mean()])
newcenter = newcenter.reshape(4,2)
centres5 = newcenter

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres5[:,0], centres5[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres4 - centres5
# Out:
# array([[-0.03289221, -0.03744027],
#        [-0.04324709, -0.01908171],
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.        ]])

# %% [markdown]
# ### Iteration 7

# %%
cluster = []
for datapoint in data:
    cluster.append(find_center(datapoint,centres5))

mycolors = []
for c in cluster:
    mycolors.append(colors[c])

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres5[:,0], centres5[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
newcenter = np.array([])
for c in range(len(centres5)):
    mypointsx = np.array([])
    mypointsy = np.array([])
    for i in range(len(data)):
        if cluster[i] == c:
            mypointsx = np.append(mypointsx, data[i,0])
            mypointsy = np.append(mypointsy, data[i,1])
    newcenter = np.append(newcenter, [mypointsx.mean(),mypointsy.mean()])
newcenter = newcenter.reshape(4,2)
centres6 = newcenter

# %%
plt.figure(figsize = (10,5))
plt.scatter(data[:,0], data[:,1], s=7, c=mycolors)
plt.scatter(centres5[:,0], centres5[:,1], color = colors, s=119, edgecolors = 'red')
plt.show()

# %%
centres5 - centres6
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %% [markdown]
# # It took 7 iterations for the centroids to finally stabilize
